# %%
import psycopg2 as ps
import pandas as pd
from sqlalchemy import create_engine

# %%
#read the input data
data=pd.read_csv("Admission_Predict_V.csv")
data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4    4   4.5  8.87
# 2             3        316          104                  3    3   3.5     8
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2    2     3  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 498         499        312          103                  4    4     5  8.43
# 499         500        327          113                  4  4.5   4.5  9.04
# 500         max        340          120                  5    5     5  9.92
# 501         min        290           92                  1    1     1   6.8
# 502  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA
#
#      Research  Chance of Admit
# ...

# %%
#the three rows in the bottom have to be deleted
data=data.drop([500,501,502])
data
# Out:
#     Serial No. GRE Score TOEFL Score University Rating  SOP LOR   CGPA  \
# 0            1       337         118                 4  4.5  4.5  9.65
# 1            2       324         107                 4    4  4.5  8.87
# 2            3       316         104                 3    3  3.5     8
# 3            4       322         110                 3  3.5  2.5  8.67
# 4            5       314         103                 2    2    3  8.21
# ..         ...       ...         ...               ...  ...  ...   ...
# 495        496       332         108                 5  4.5    4  9.02
# 496        497       337         117                 5    5    5  9.87
# 497        498       330         120                 5  4.5    5  9.56
# 498        499       312         103                 4    4    5  8.43
# 499        500       327         113                 4  4.5  4.5  9.04
#
#     Research Chance of Admit
# 0          1             0.92
# 1          1             0.76
# ...

# %%
#connecting to postgrelsql and create the database
conn = ps.connect(
                        user='postgres', password='88042425', 
                        host='127.0.0.1', port='5432'
)
  
conn.autocommit = True
cursor = conn.cursor()
print("Connected!")


sql = '''CREATE database Admission_predict_db''';
cursor.execute(sql)
conn.get_dsn_parameters()

print("Database created successfully........")
conn.commit()
conn.close()
# Out:
# Connected!
# Database created successfully........

# %%
#creating the table in the above database

conn = ps.connect(database='admission_predict_db',
                        user='postgres', password='88042425', 
                        host='127.0.0.1', port='5432'
)
  
# conn.autocommit = True
cursor = conn.cursor()
print("Connected!")
  
sql = '''CREATE TABLE Admission_Predict("Serial No" int NOT NULL,\
"GRE Score" int NOT NULL,\
"TOEFL Score" int NOT NULL, "University Rating" int NOT NULL,\
SOP float NOT NULL, "LOR " float NOT NULL, CGPA float NOT NULL,\
Research int NOT NULL, "Chance of Admit " float NOT NULL);'''
print("table is created successfully")

# # sql = '''CREATE TABLE Admission_Predict_V1("Serial No." int NOT NULL,\
# # "GRE Score" int NOT NULL,\
# # "TOEFL Score" int NOT NULL, "University Rating" int NOT NULL,\
# # SOP float NOT NULL, LOR float NOT NULL, CGPA float NOT NULL,\
# # Research int NOT NULL, "Chance of Admit" float);'''
  
cursor.execute(sql)
conn.commit()
# Out:
# Connected!
# table is created successfully

# %% [markdown]
# solution 1 to load the data into the table with create_engine and to_sql:

# %%
#solution 1 to load the data into the table
#create a engine to connect to the database that is created in above
#engine=create_engine("postgresql+psycopg2://yourusername:yourpassword@localhost:port/database name") 
engine=create_engine("postgresql+psycopg2://postgres:88042425@localhost:5432/admission_predict_db")

# %%
data.to_sql('admission_predict', engine, if_exists= 'replace',index= False)
engine.dispose()

# %% [markdown]
# solution 2 to load the dataset into the table directly from csv file:

# %%
##second solution to load the dataset into the table 
# cursor = conn.cursor()

# with open('admission.csv', 'r') as f:
#     next(f)
#     cursor.copy_from(f, 'admission_predict', sep=',')

# conn.commit()

# %%
#using sql query to read the data from the table
sql3 = '''select * from admission_Predict;'''
cursor.execute(sql3)
for i in cursor.fetchall():
    print(i)
# Out:
# ('1', '337', '118', '4', '4.5', '4.5', '9.65', '1', '0.92')
# ('2', '324', '107', '4', '4', '4.5', '8.87', '1', '0.76')
# ('3', '316', '104', '3', '3', '3.5', '8', '1', '0.72')
# ('4', '322', '110', '3', '3.5', '2.5', '8.67', '1', '0.8')
# ('5', '314', '103', '2', '2', '3', '8.21', '0', '0.65')
# ('6', '330', '115', '5', '4.5', '3', '9.34', '1', '0.9')
# ('7', '321', '109', '3', '3', '4', '8.2', '1', '0.75')
# ('8', '308', '101', '2', '3', '4', '7.9', '0', '0.68')
# ('9', '302', '102', '1', '2', '1.5', '8', '0', '0.5')
# ('10', '323', '108', '3', '3.5', '3', '8.6', '0', '0.45')
# ('11', '325', '106', '3', '3.5', '4', '8.4', '1', '0.52')
# ('12', '327', '111', '4', '4', '4.5', '9', '1', '0.84')
# ('13', '328', '112', '4', '4', '4.5', '9.1', '1', '0.78')
# ('14', '307', '109', '3', '4', '3', '8', '1', '0.62')
# ('15', '311', '104', '3', '3.5', '2', '8.2', '1', '0.61')
# ('16', '314', '105', '3', '3.5', '2.5', '8.3', '0', '0.54')
# ...

# %%
sql4=''' select "TOEFL Score" from Admission_Predict;'''
cursor.execute(sql4)
model1=cursor.fetchall()
model1
# Out:
# [('118',),
#  ('107',),
#  ('104',),
#  ('110',),
#  ('103',),
#  ('115',),
#  ('109',),
#  ('101',),
#  ('102',),
#  ('108',),
#  ('106',),
#  ('111',),
#  ('112',),
#  ('109',),
#  ('104',),
#  ('105',),
#  ('107',),
#  ('106',),
#  ('110',),
#  ('102',),
#  ('107',),
#  ('114',),
#  ('116',),
#  ('119',),
#  ('119',),
#  ('120',),
#  ('109',),
#  ('98',),
#  ('93',),
#  ('99',),
#  ('97',),
#  ('103',),
#  ('118',),
#  ('114',),
#  ('112',),
#  ('110',),
#  ('106',),
#  ('105',),
#  ('105',),
#  ('108',),
#  ('110',),
#  ('105',),
#  ('107',),
#  ('117',),
#  ('113',),
#  ('110',),
#  ('114',),
#  ('119',),
#  ('110',),
#  ('111',),
#  ('98',),
#  ('100',),
#  ('116',),
#  ('112',),
#  ('110',),
#  ('103',),
#  ('102',),
#  ('99',),
#  ('99',),
#  ('104',),
#  ('100',),
#  ('101',),
#  ('105',),
#  ('107',),
#  ('111',),
#  ('112',),
#  ('114',),
#  ('107',),
#  ('109',),
#  ('115',),
#  ('118',),
#  ('112',),
#  ('111',),
#  ('108',),
#  ('106',),
#  ('114',),
#  ('112',),
# ...

# %%
sql6=''' SELECT * FROM Admission_Predict WHERE "TOEFL Score" = '118';'''
cursor.execute(sql6)
model2=cursor.fetchall()
model2
# Out:
# [('1', '337', '118', '4', '4.5', '4.5', '9.65', '1', '0.92'),
#  ('33', '338', '118', '4', '3', '4.5', '9.4', '1', '0.91'),
#  ('71', '332', '118', '5', '5', '5', '9.64', '1', '0.94'),
#  ('130', '333', '118', '5', '5', '5', '9.35', '1', '0.92'),
#  ('142', '332', '118', '2', '4.5', '3.5', '9.36', '1', '0.9'),
#  ('188', '335', '118', '5', '4.5', '3.5', '9.44', '1', '0.93'),
#  ('194', '336', '118', '5', '4.5', '5', '9.53', '1', '0.94'),
#  ('287', '336', '118', '5', '4.5', '4', '9.19', '1', '0.92'),
#  ('338', '332', '118', '5', '5', '5', '9.47', '1', '0.94'),
#  ('447', '327', '118', '4', '5', '5', '9.67', '1', '0.93')]

# %%
sql7=''' SELECT * FROM Admission_Predict WHERE "LOR " = '4.5';'''
cursor.execute(sql7)
model3=cursor.fetchall()
model3
# Out:
# [('1', '337', '118', '4', '4.5', '4.5', '9.65', '1', '0.92'),
#  ('2', '324', '107', '4', '4', '4.5', '8.87', '1', '0.76'),
#  ('12', '327', '111', '4', '4', '4.5', '9', '1', '0.84'),
#  ('13', '328', '112', '4', '4', '4.5', '9.1', '1', '0.78'),
#  ('24', '334', '119', '5', '5', '4.5', '9.7', '1', '0.95'),
#  ('26', '340', '120', '5', '4.5', '4.5', '9.6', '1', '0.94'),
#  ('33', '338', '118', '4', '3', '4.5', '9.4', '1', '0.91'),
#  ('51', '313', '98', '3', '2.5', '4.5', '8.3', '1', '0.76'),
#  ('83', '320', '110', '5', '5', '4.5', '9.22', '1', '0.92'),
#  ('84', '322', '115', '5', '4', '4.5', '9.36', '1', '0.92'),
#  ('85', '340', '115', '5', '4.5', '4.5', '9.45', '1', '0.94'),
#  ('99', '332', '119', '4', '5', '4.5', '9.24', '1', '0.9'),
#  ('106', '316', '110', '3', '4', '4.5', '8.78', '1', '0.69'),
#  ('107', '329', '111', '4', '4.5', '4.5', '9.18', '1', '0.87'),
#  ('108', '338', '117', '4', '3.5', '4.5', '9.46', '1', '0.91'),
# ...

# %%
sql8=''' SELECT "LOR " FROM Admission_Predict WHERE "Chance of Admit " = '0.87';'''
cursor.execute(sql8)
model4=cursor.fetchall()
model4
# Out:
# [('4',), ('4.5',), ('4',), ('5',), ('3.5',), ('4.5',), ('4',), ('4',)]

# %%
df= pd.read_sql_query('''SELECT * FROM Admission_Predict''', con=conn)
df
# Out:
# C:\Users\16476\anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     Serial No. GRE Score TOEFL Score University Rating  SOP LOR   CGPA  \
# 0            1       337         118                 4  4.5  4.5  9.65
# 1            2       324         107                 4    4  4.5  8.87
# 2            3       316         104                 3    3  3.5     8
# 3            4       322         110                 3  3.5  2.5  8.67
# 4            5       314         103                 2    2    3  8.21
# ..         ...       ...         ...               ...  ...  ...   ...
# 495        496       332         108                 5  4.5    4  9.02
# 496        497       337         117                 5    5    5  9.87
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    object
#  1   GRE Score          500 non-null    object
#  2   TOEFL Score        500 non-null    object
#  3   University Rating  500 non-null    object
#  4   SOP                500 non-null    object
#  5   LOR                500 non-null    object
#  6   CGPA               500 non-null    object
#  7   Research           500 non-null    object
#  8   Chance of Admit    500 non-null    object
# dtypes: object(9)
# memory usage: 35.3+ KB
